# %%
import pandas as pd
import os
from matplotlib import pyplot
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import os
# ----> 3 from matplotlib import pyplot
#       4 import re
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import src.json_file as js
json_path=js.JsonFile().get_json_files()
json_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import src.json_file as js
#       2 json_path=js.JsonFile().get_json_files()
#       3 json_path
#
# File c:\Users\Joshmen\Desktop\Smart Shelf Life Prediction Model\src\json_file.py:1
# ----> 1 from data_loader import DataLoader
#       2 from typing import Any
#       3 import re
#
# ModuleNotFoundError: No module named 'data_loader'

# %%
import json

data=[]
for i in json_path:
    with open(i,'r') as js:
        file=json.load(js)
        samples=file['samples'][0]
        for img in samples['images']:
            data.append(img)

data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 import json
#       2
#       3 data=[]
# ----> 4 for i in json_path:
#       5     with open(i,'r') as js:
#       6         file=json.load(js)
#       7         samples=file['samples'][0]
#
# NameError: name 'json_path' is not defined

# %%
# Out:
# 0
